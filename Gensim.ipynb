# %%
import gensim.downloader as api

# %%
glove_model = api.load("glove-twitter-25")

# %%
len(model.word_vec("debt"))
# Out:
# 25

# %%
def dump(obj):
  for attr in dir(obj):
    print("obj.%s = %r" % (attr, getattr(obj, attr)))

# %%
dump(model)
# Out:
# im.models.keyedvectors.Vocab object at 0x13ff1d160>, '金銭': <gensim.models.keyedvectors.Vocab object at 0x13ff1d190>, '間違いないww': <gensim.models.keyedvectors.Vocab object at 0x13ff1d1c0>, '関ジュ福岡': <gensim.models.keyedvectors.Vocab object at 0x13ff1d1f0>, '関東の天気': <gensim.models.keyedvectors.Vocab object at 0x13ff1d220>, '青の': <gensim.models.keyedvectors.Vocab object at 0x13ff1d2e0>, '音楽劇': <gensim.models.keyedvectors.Vocab object at 0x13ff1d340>, '香菜ちゃん': <gensim.models.keyedvectors.Vocab object at 0x13ff1d3d0>, '駅にいたリア充の会話': <gensim.models.keyedvectors.Vocab object at 0x13ff1d430>, '高いw': <gensim.models.keyedvectors.Vocab object at 0x13ff1d460>, '高橋美佳子': <gensim.models.keyedvectors.Vocab object at 0x13ff1d490>, '黄瀬ぇ': <gensim.models.keyedvectors.Vocab object at 0x13ff1d520>, '가감없이': <gensim.models.keyedvectors.Vocab object at 0x13ff1d5e0>, '가면갈수록': <gensim.models.keyedvectors.Vocab object at 0x13ff1d610>, '가수상': <gensim.models.keyedvectors.Vocab object at 0x13ff1d670>, '가수와': <gensim.
# ...
